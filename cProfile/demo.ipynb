# %%
python3 -m cProfile -o result.prof main.py "评价一下 马刺队"
python3 -m snakeviz result.prof

# %% [markdown]
# 运行不了py-spy
# 权限开了还是不行！

# %%
import cProfile
import re

cProfile.run('re.compile("foo|bar")')
cProfile.run('re.compile("foo|bar")', "restats")
# Out:
#          231 function calls (224 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:226(compile)
#         1    0.000    0.000    0.000    0.000 __init__.py:280(_compile)
#         1    0.000    0.000    0.000    0.000 _compiler.py:216(_compile_charset)
#         1    0.000    0.000    0.000    0.000 _compiler.py:243(_optimize_charset)
#       3/1    0.000    0.000    0.000    0.000 _compiler.py:37(_compile)
#         2    0.000    0.000    0.000    0.000 _compiler.py:428(_get_iscased)
#         1    0.000    0.000    0.000    0.000 _compiler.py:436(_get_literal_prefix)
#         1    0.000    0.000    0.000    0.000 _compiler.py:467(_get_charset_prefix)
#         1    0.000    0.000    0.000    0.000 _compiler.py:511(_compile_info)
# ...

# %%
import pstats

p = pstats.Stats("restats")

# %%
import cProfile
import pstats
from pstats import SortKey

pr = cProfile.Profile()

pr.enable()
# 只把你关心的代码放这里
pr.disable()

p = pstats.Stats(pr)

pstats.Stats(pr).strip_dirs().sort_stats(SortKey.CUMULATIVE).print_stats()

# %%
import io
import pstats

s = io.StringIO()
p = pstats.Stats("restats", stream=s)

# %%
p = pstats.Stats("restats1")
p.add("restats2")
p.sort_stats("cumtime").print_stats(20)

p.dump_stats("merged.prof")

# %%
import cProfile
import pstats
from pstats import SortKey

def main():
    # 你的程序入口
    pass

with cProfile.Profile() as pr:
    main()

pstats.Stats(pr).strip_dirs().sort_stats(SortKey.CUMULATIVE).print_stats(20)

# %%
py-spy

py-spy top --pid <PID> #实时看热点
py-spy record -o profile.svg --pid <PID> #生成火焰图。
py-spy dump --pid <PID> #程序卡住时，看当前调用栈。
