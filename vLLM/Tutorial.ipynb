# %% [markdown]
# 导入模型

# %%
vllm serve meta-llama/Llama-3.1-8B \

# %% [markdown]
# 设置上下文限制

# %%
vllm serve meta-llama/Llama-3.1-8B \
  --max-model-len 4096

# %% [markdown]
# 运行之后 在另一个终端运行

# %%
python 测试程序的路径
